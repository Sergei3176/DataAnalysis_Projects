# %% [markdown]
# Ссылка на дашборд "Диаграмма распределения заработной платы клиентов", с индикатором, отбражающим % держателей кредитных карт в каждом bin'е и фильтром по CHURN.

# %% [markdown]
# https://public.tableau.com/app/profile/sergei.kinev/viz/CHURN_16816495036860/Dashboard?publish=yes

# %% [markdown]
# ![image.png](attachment:image.png)
